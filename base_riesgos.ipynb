# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np

file_path = r"/content/drive/MyDrive/Algoritmia y Programación/Riesgos_corazon.csv"
data = pd.read_csv(file_path)
data
# Out:
#        index     id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  \
# 0          0      0  18393       2     168    62.0    110     80            1
# 1          1      1  20228       1     156    85.0    140     90            3
# 2          2      2  18857       1     165    64.0    130     70            3
# 3          3      3  17623       2     169    82.0    150    100            1
# 4          4      4  17474       1     156    56.0    100     60            1
# ...      ...    ...    ...     ...     ...     ...    ...    ...          ...
# 69995  69995  99993  19240       2     168    76.0    120     80            1
# 69996  69996  99995  22601       1     158   126.0    140     90            2
# 69997  69997  99996  19066       2     183   105.0    180     90            3
# 69998  69998  99998  22431       1     163    72.0    135     80            1
# 69999  69999  99999  20540       1     170    72.0    120     80            2
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70000 entries, 0 to 69999
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   index        70000 non-null  int64
#  1   id           70000 non-null  int64
#  2   age          70000 non-null  int64
#  3   gender       70000 non-null  int64
#  4   height       70000 non-null  int64
#  5   weight       70000 non-null  float64
#  6   ap_hi        70000 non-null  int64
#  7   ap_lo        70000 non-null  int64
#  8   cholesterol  70000 non-null  int64
#  9   gluc         70000 non-null  int64
#  10  smoke        70000 non-null  int64
#  11  alco         70000 non-null  int64
#  12  active       70000 non-null  int64
#  13  cardio       70000 non-null  int64
# dtypes: float64(1), int64(13)
# memory usage: 7.5 MB

# %%
data.describe()
# Out:
#               index            id           age        gender        height  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean   34999.500000  49972.419900  19468.865814      1.349571    164.359229
# std    20207.403759  28851.302323   2467.251667      0.476838      8.210126
# min        0.000000      0.000000  10798.000000      1.000000     55.000000
# 25%    17499.750000  25006.750000  17664.000000      1.000000    159.000000
# 50%    34999.500000  50001.500000  19703.000000      1.000000    165.000000
# 75%    52499.250000  74889.250000  21327.000000      2.000000    170.000000
# max    69999.000000  99999.000000  23713.000000      2.000000    250.000000
#
#              weight         ap_hi         ap_lo   cholesterol          gluc  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean      74.205690    128.817286     96.630414      1.366871      1.226457
# ...

# %%
print(data.isna().sum())
# Out:
# index          0
# id             0
# age            0
# gender         0
# height         0
# weight         0
# ap_hi          0
# ap_lo          0
# cholesterol    0
# gluc           0
# smoke          0
# alco           0
# active         0
# cardio         0
# dtype: int64

# %%
print(data.isnull().sum())
# Out:
# index          0
# id             0
# age            0
# gender         0
# height         0
# weight         0
# ap_hi          0
# ap_lo          0
# cholesterol    0
# gluc           0
# smoke          0
# alco           0
# active         0
# cardio         0
# dtype: int64

# %%
print(data.duplicated().sum())
# Out:
# 0

# %%
print(data.duplicated())
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 69995    False
# 69996    False
# 69997    False
# 69998    False
# 69999    False
# Length: 70000, dtype: bool

# %% [markdown]
# **ENFOQUE:Demografico/epidemiológico**
# se puede analizar cómo la enfermedad cardiovascular afecta a distintos grupos según su edad, género y hábitos de vida. No incluye datos clínicos como peso o presión, ya que se enfoca más en los patrones generales de la población que en detalles médicos.Además, no borré el ID para evitar duplicados ya que cada fila corresponde a un usuario diferente, y en las respuestas puede coincidir unas filas con otras pero siguen siendo de diferente persona.

# %%
data.columns
# Out:
# Index(['index', 'id', 'age', 'gender', 'height', 'weight', 'ap_hi', 'ap_lo',
#        'cholesterol', 'gluc', 'smoke', 'alco', 'active', 'cardio'],
#       dtype='object')

# %%
data.drop(["index", "height", "weight", "ap_hi", "ap_lo"], axis=1, inplace=True)

# %%
data.columns
# Out:
# Index(['id', 'age', 'gender', 'cholesterol', 'gluc', 'smoke', 'alco', 'active',
#        'cardio'],
#       dtype='object')
